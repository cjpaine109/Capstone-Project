# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam
from keras.layers import Dropout
from keras import regularizers
import yfinance as yf
import pandas as pd
import numpy as np
import pandas_ta as ta 

# Load the data
data = yf.download('GOOGL', start='2004-08-19', end='2024-01-01')

# Add new features
data['RSI'] = ta.rsi(data['Close'])
data['OBV'] = ta.obv(data['Close'], data['Volume'])
data['ATR'] = ta.atr(data['High'], data['Low'], data['Close'])
data['Yearly_MA'] = data['Close'].rolling(window=256).mean()
data['Garman Klass Vol'] = ((np.log(data['High']) - np.log(data['Low'])) ** 2) / 2 - (2 * np.log(2) - 1) * ((np.log(data['Adj Close']) - np.log(data['Open'])) ** 2)
data['Day'] = data.index.dayofweek
data['Month'] = data.index.month
data['Year'] = data.index.year

# Drop missing values
data = data.dropna()

# Keep only the 'Close' and the new features
data = data[['Close', 'RSI', 'OBV', 'ATR', 'Yearly_MA', 'Garman Klass Vol', 'Day', 'Month', 'Year']]

# Create a correlation matrix with the target 'Close'
correlation_matrix = data.corr()['Close'].sort_values(ascending=False)
print(correlation_matrix)

# Visualize correlation matrix, so we can read each feature clearly
plt.figure(figsize=(10, 7))
plt.bar(correlation_matrix.index, correlation_matrix.values)
plt.title('Correlation Matrix with Close', fontsize=16)
plt.xlabel('Features')
plt.ylabel('Correlation with Close')
plt.xticks(rotation=45)
plt.show()

# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = pd.DataFrame(scaler.fit_transform(data), columns=data.columns, index=data.index)

# Create a separate scaler for 'Close' prices
close_scaler = MinMaxScaler(feature_range=(0, 1))
close_scaler.fit(data[['Close']])

# Split into training and testing sets (80% training, 20% testing)
train_size = int(len(data_scaled) * 0.8)
train, test = data_scaled.iloc[0:train_size, :], data_scaled.iloc[train_size:len(data_scaled), :]

# Function to create a dataset for LSTM
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset.iloc[i:(i+look_back), 1:]  # Use only the features for input
        X.append(a.values)
        Y.append(dataset.iloc[i + look_back, 0])  # Use 'Close' for output
    return np.array(X), np.array(Y)

# Create datasets for training and testing
look_back = 10
X_train, Y_train = create_dataset(train, look_back)
X_test, Y_test = create_dataset(test, look_back)

# Reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# Adjust the learning rate
optimizer = Adam(learning_rate=0.0001)

model = Sequential()
model.add(LSTM(250, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2]), bias_regularizer=regularizers.l2(0.05)))
model.add(Dropout(0.2))
model.add(LSTM(250, bias_regularizer=regularizers.l2(0.05)))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer=optimizer)

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=5)

# Train the model
model.fit(X_train, Y_train, epochs=100, batch_size=64, verbose=2, validation_split=0.2, callbacks=[early_stopping])

# Predict the stock prices on the testing data
predictions = model.predict(X_test)
predictions = close_scaler.inverse_transform(predictions)  # Use the 'close_scaler' here

from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# Calculate the RMSE, MSE and R² for the test set
Y_test_transformed = close_scaler.inverse_transform(Y_test.reshape(-1, 1)).flatten()

# Calculate the RMSE, MSE, and R² for the test set
mae = mean_absolute_error(Y_test_transformed, predictions.flatten())
mse = mean_squared_error(Y_test_transformed, predictions.flatten())
r2 = r2_score(Y_test_transformed, predictions.flatten())

print('MAE:', mae)
print('MSE:', mse)
print('R²:', r2)

# Calculate the average difference between the actual and predicted values as a percentage
average_difference = np.mean(np.abs(predictions.flatten() - Y_test_transformed) / Y_test_transformed) * 100
print(f"Average difference between actual and predicted values: {average_difference:.2f}%")

# Compare the predicted prices with the actual values
Y_test = close_scaler.inverse_transform([Y_test])  # Use the 'close_scaler' here
plt.plot(Y_test[0])
plt.plot(predictions[:, 0])
plt.title('Google Stock Price Prediction', fontsize=16)
plt.legend(['Actual', 'Predicted'])
plt.show()

# Plot train loss vs validation loss
history = model.fit(X_train, Y_train, epochs=100, batch_size=64, verbose=2, validation_split=0.2, callbacks=[early_stopping])
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Print overfitting or not
if history.history['val_loss'][-1] < history.history['loss'][-1]:
    print('The model is not overfitting')
else:
    print('The model is overfitting')

# Create a Niave forecast
data['Naive'] = data['Close'].shift(1)
data = data.dropna()

# Plot the naive forecast
plt.plot(data['Close'], label='Actual')
plt.plot(data['Naive'], label='Naive')
plt.legend()
plt.show()

# Compare Niave forecast with LSTM forecast
plt.plot(data['Close'][-100:], label='Actual')
plt.plot(data['Naive'][-100:], label='Naive')
plt.plot(data['Close'][-100:].index, predictions[-100:], label='LSTM')
plt.title('Google Stock Price Prediction', fontsize=16)
plt.legend()
plt.show()
# Out:
# WARNING:tensorflow:From c:\Users\cjpai\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# c:\Users\cjpai\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# Close               1.000000
# Yearly_MA           0.969494
# ATR                 0.911990
# Year                0.884935
# OBV                 0.748379
# RSI                 0.045139
# Month               0.039305
# Day                 0.002221
# Garman Klass Vol   -0.048113
# Name: Close, dtype: float64
# WARNING:tensorflow:From c:\Users\cjpai\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Epoch 1/100
# WARNING:tensorflow:From c:\Users\cjpai\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 47/47 - 6s - loss: 24.8914 - val_loss: 24.7744 - 6s/epoch - 132ms/step
# Epoch 2/100
# 47/47 - 2s - loss: 24.6547 - val_loss: 24.5379 - 2s/epoch - 40ms/step
# Epoch 3/100
# 47/47 - 2s - loss: 24.4226 - val_loss: 24.3062 - 2s/epoch - 39ms/step
# Epoch 4/100
# 47/47 - 2s - loss: 24.1922 - val_loss: 24.0761 - 2s/epoch - 38ms/step
# Epoch 5/100
# 47/47 - 2s - loss: 23.9634 - val_loss: 23.8490 - 2s/epoch - 39ms/step
# Epoch 6/100
# 47/47 - 2s - loss: 23.7362 - val_loss: 23.6207 - 2s/epoch - 38ms/step
# Epoch 7/100
# 47/47 - 2s - loss: 23.5106 - val_loss: 23.3961 - 2s/epoch - 40ms/step
# Epoch 8/100
# 47/47 - 2s - loss: 23.2866 - val_loss: 23.1726 - 2s/epoch - 39ms/step
# Epoch 9/100
# 47/47 - 2s - loss: 23.0641 - val_loss: 22.9503 - 2s/epoch - 38ms/step
# Epoch 10/100
# 47/47 - 2s - loss: 22.8432 - val_loss: 22.7299 - 2s/epoch - 39ms/step
# Epoch 11/100
# 47/47 - 2s - loss: 22.6238 - val_loss: 22.5114 - 2s/epoch - 38ms/step
# Epoch 12/100
# 47/47 - 2s - loss: 22.4059 - val_loss: 22.2944 - 2s/epoch - 39ms/step
# Epoch 13/100
# 47/47 - 2s - loss: 22.1895 - val_loss: 22.0787 - 2s/epoch - 38ms/step
# Epoch 14/100
# 47/47 - 2s - loss: 21.9746 - val_loss: 21.8644 - 2s/epoch - 38ms/step
# Epoch 15/100
# 47/47 - 2s - loss: 21.7612 - val_loss: 21.6519 - 2s/epoch - 38ms/step
# Epoch 16/100
# 47/47 - 2s - loss: 21.5493 - val_loss: 21.4405 - 2s/epoch - 40ms/step
# Epoch 17/100
# 47/47 - 2s - loss: 21.3388 - val_loss: 21.2308 - 2s/epoch - 42ms/step
# Epoch 18/100
# 47/47 - 2s - loss: 21.1297 - val_loss: 21.0225 - 2s/epoch - 41ms/step
# Epoch 19/100
# 47/47 - 2s - loss: 20.9221 - val_loss: 20.8156 - 2s/epoch - 41ms/step
# Epoch 20/100
# 47/47 - 2s - loss: 20.7158 - val_loss: 20.6102 - 2s/epoch - 42ms/step
# Epoch 21/100
# 47/47 - 2s - loss: 20.5110 - val_loss: 20.4061 - 2s/epoch - 39ms/step
# Epoch 22/100
# 47/47 - 2s - loss: 20.3076 - val_loss: 20.2034 - 2s/epoch - 39ms/step
# Epoch 23/100
# 47/47 - 2s - loss: 20.1055 - val_loss: 20.0020 - 2s/epoch - 41ms/step
# Epoch 24/100
# 47/47 - 2s - loss: 19.9049 - val_loss: 19.8021 - 2s/epoch - 41ms/step
# Epoch 25/100
# 47/47 - 2s - loss: 19.7056 - val_loss: 19.6035 - 2s/epoch - 39ms/step
# Epoch 26/100
# 47/47 - 2s - loss: 19.5076 - val_loss: 19.4062 - 2s/epoch - 38ms/step
# Epoch 27/100
# 47/47 - 2s - loss: 19.3110 - val_loss: 19.2102 - 2s/epoch - 38ms/step
# Epoch 28/100
# 47/47 - 2s - loss: 19.1157 - val_loss: 19.0157 - 2s/epoch - 38ms/step
# Epoch 29/100
# 47/47 - 2s - loss: 18.9217 - val_loss: 18.8224 - 2s/epoch - 38ms/step
# Epoch 30/100
# 47/47 - 2s - loss: 18.7290 - val_loss: 18.6307 - 2s/epoch - 38ms/step
# Epoch 31/100
# 47/47 - 2s - loss: 18.5377 - val_loss: 18.4399 - 2s/epoch - 39ms/step
# Epoch 32/100
# 47/47 - 2s - loss: 18.3476 - val_loss: 18.2504 - 2s/epoch - 38ms/step
# Epoch 33/100
# 47/47 - 2s - loss: 18.1588 - val_loss: 18.0624 - 2s/epoch - 38ms/step
# Epoch 34/100
# 47/47 - 2s - loss: 17.9713 - val_loss: 17.8755 - 2s/epoch - 39ms/step
# Epoch 35/100
# 47/47 - 2s - loss: 17.7851 - val_loss: 17.6900 - 2s/epoch - 39ms/step
# Epoch 36/100
# 47/47 - 2s - loss: 17.6001 - val_loss: 17.5060 - 2s/epoch - 38ms/step
# Epoch 37/100
# 47/47 - 2s - loss: 17.4164 - val_loss: 17.3225 - 2s/epoch - 39ms/step
# Epoch 38/100
# 47/47 - 2s - loss: 17.2338 - val_loss: 17.1411 - 2s/epoch - 39ms/step
# Epoch 39/100
# 47/47 - 2s - loss: 17.0526 - val_loss: 16.9601 - 2s/epoch - 39ms/step
# Epoch 40/100
# 47/47 - 2s - loss: 16.8725 - val_loss: 16.7805 - 2s/epoch - 38ms/step
# Epoch 41/100
# 47/47 - 2s - loss: 16.6937 - val_loss: 16.6024 - 2s/epoch - 38ms/step
# Epoch 42/100
# 47/47 - 2s - loss: 16.5161 - val_loss: 16.4254 - 2s/epoch - 38ms/step
# Epoch 43/100
# 47/47 - 2s - loss: 16.3397 - val_loss: 16.2498 - 2s/epoch - 38ms/step
# Epoch 44/100
# 47/47 - 2s - loss: 16.1645 - val_loss: 16.0750 - 2s/epoch - 39ms/step
# Epoch 45/100
# 47/47 - 2s - loss: 15.9904 - val_loss: 15.9017 - 2s/epoch - 38ms/step
# Epoch 46/100
# 47/47 - 2s - loss: 15.8176 - val_loss: 15.7296 - 2s/epoch - 39ms/step
# Epoch 47/100
# 47/47 - 2s - loss: 15.6459 - val_loss: 15.5587 - 2s/epoch - 38ms/step
# Epoch 48/100
# 47/47 - 2s - loss: 15.4754 - val_loss: 15.3887 - 2s/epoch - 38ms/step
# Epoch 49/100
# 47/47 - 2s - loss: 15.3061 - val_loss: 15.2197 - 2s/epoch - 39ms/step
# Epoch 50/100
# 47/47 - 2s - loss: 15.1379 - val_loss: 15.0527 - 2s/epoch - 39ms/step
# Epoch 51/100
# 47/47 - 2s - loss: 14.9709 - val_loss: 14.8860 - 2s/epoch - 38ms/step
# Epoch 52/100
# 47/47 - 2s - loss: 14.8050 - val_loss: 14.7208 - 2s/epoch - 38ms/step
# Epoch 53/100
# 47/47 - 2s - loss: 14.6402 - val_loss: 14.5567 - 2s/epoch - 38ms/step
# Epoch 54/100
# 47/47 - 2s - loss: 14.4766 - val_loss: 14.3942 - 2s/epoch - 39ms/step
# Epoch 55/100
# 47/47 - 2s - loss: 14.3141 - val_loss: 14.2315 - 2s/epoch - 38ms/step
# Epoch 56/100
# 47/47 - 2s - loss: 14.1527 - val_loss: 14.0717 - 2s/epoch - 40ms/step
# Epoch 57/100
# 47/47 - 2s - loss: 13.9924 - val_loss: 13.9111 - 2s/epoch - 38ms/step
# Epoch 58/100
# 47/47 - 2s - loss: 13.8333 - val_loss: 13.7531 - 2s/epoch - 38ms/step
# Epoch 59/100
# 47/47 - 2s - loss: 13.6752 - val_loss: 13.5954 - 2s/epoch - 38ms/step
# Epoch 60/100
# 47/47 - 2s - loss: 13.5183 - val_loss: 13.4388 - 2s/epoch - 39ms/step
# Epoch 61/100
# 47/47 - 2s - loss: 13.3624 - val_loss: 13.2836 - 2s/epoch - 38ms/step
# Epoch 62/100
# 47/47 - 2s - loss: 13.2076 - val_loss: 13.1292 - 2s/epoch - 38ms/step
# Epoch 63/100
# 47/47 - 2s - loss: 13.0539 - val_loss: 12.9769 - 2s/epoch - 38ms/step
# Epoch 64/100
# 47/47 - 2s - loss: 12.9013 - val_loss: 12.8239 - 2s/epoch - 38ms/step
# Epoch 65/100
# 47/47 - 2s - loss: 12.7498 - val_loss: 12.6732 - 2s/epoch - 38ms/step
# Epoch 66/100
# 47/47 - 2s - loss: 12.5993 - val_loss: 12.5240 - 2s/epoch - 38ms/step
# Epoch 67/100
# 47/47 - 2s - loss: 12.4499 - val_loss: 12.3747 - 2s/epoch - 38ms/step
# Epoch 68/100
# 47/47 - 2s - loss: 12.3016 - val_loss: 12.2275 - 2s/epoch - 38ms/step
# Epoch 69/100
# 47/47 - 2s - loss: 12.1543 - val_loss: 12.0802 - 2s/epoch - 38ms/step
# Epoch 70/100
# 47/47 - 2s - loss: 12.0080 - val_loss: 11.9341 - 2s/epoch - 38ms/step
# Epoch 71/100
# 47/47 - 2s - loss: 11.8629 - val_loss: 11.7906 - 2s/epoch - 39ms/step
# Epoch 72/100
# 47/47 - 2s - loss: 11.7187 - val_loss: 11.6466 - 2s/epoch - 39ms/step
# Epoch 73/100
# 47/47 - 2s - loss: 11.5757 - val_loss: 11.5034 - 2s/epoch - 38ms/step
# Epoch 74/100
# 47/47 - 2s - loss: 11.4336 - val_loss: 11.3624 - 2s/epoch - 38ms/step
# Epoch 75/100
# 47/47 - 2s - loss: 11.2926 - val_loss: 11.2215 - 2s/epoch - 39ms/step
# Epoch 76/100
# 47/47 - 2s - loss: 11.1526 - val_loss: 11.0824 - 2s/epoch - 38ms/step
# Epoch 77/100
# 47/47 - 2s - loss: 11.0136 - val_loss: 10.9447 - 2s/epoch - 39ms/step
# Epoch 78/100
# 47/47 - 2s - loss: 10.8757 - val_loss: 10.8068 - 2s/epoch - 42ms/step
# Epoch 79/100
# 47/47 - 2s - loss: 10.7387 - val_loss: 10.6703 - 2s/epoch - 39ms/step
# Epoch 80/100
# 47/47 - 2s - loss: 10.6028 - val_loss: 10.5356 - 2s/epoch - 38ms/step
# Epoch 81/100
# 47/47 - 2s - loss: 10.4679 - val_loss: 10.4003 - 2s/epoch - 39ms/step
# Epoch 82/100
# 47/47 - 2s - loss: 10.3341 - val_loss: 10.2668 - 2s/epoch - 38ms/step
# Epoch 83/100
# 47/47 - 2s - loss: 10.2012 - val_loss: 10.1353 - 2s/epoch - 38ms/step
# Epoch 84/100
# 47/47 - 2s - loss: 10.0693 - val_loss: 10.0032 - 2s/epoch - 38ms/step
# Epoch 85/100
# 47/47 - 2s - loss: 9.9384 - val_loss: 9.8727 - 2s/epoch - 40ms/step
# Epoch 86/100
# 47/47 - 2s - loss: 9.8086 - val_loss: 9.7438 - 2s/epoch - 47ms/step
# Epoch 87/100
# 47/47 - 2s - loss: 9.6797 - val_loss: 9.6153 - 2s/epoch - 40ms/step
# Epoch 88/100
# 47/47 - 2s - loss: 9.5518 - val_loss: 9.4882 - 2s/epoch - 40ms/step
# Epoch 89/100
# 47/47 - 2s - loss: 9.4249 - val_loss: 9.3613 - 2s/epoch - 39ms/step
# Epoch 90/100
# 47/47 - 2s - loss: 9.2990 - val_loss: 9.2365 - 2s/epoch - 39ms/step
# Epoch 91/100
# 47/47 - 2s - loss: 9.1740 - val_loss: 9.1118 - 2s/epoch - 39ms/step
# Epoch 92/100
# 47/47 - 2s - loss: 9.0501 - val_loss: 8.9884 - 2s/epoch - 40ms/step
# Epoch 93/100
# 47/47 - 2s - loss: 8.9271 - val_loss: 8.8670 - 2s/epoch - 38ms/step
# Epoch 94/100
# 47/47 - 2s - loss: 8.8051 - val_loss: 8.7453 - 2s/epoch - 37ms/step
# Epoch 95/100
# 47/47 - 2s - loss: 8.6841 - val_loss: 8.6238 - 2s/epoch - 37ms/step
# Epoch 96/100
# 47/47 - 2s - loss: 8.5641 - val_loss: 8.5052 - 2s/epoch - 38ms/step
# Epoch 97/100
# 47/47 - 2s - loss: 8.4450 - val_loss: 8.3872 - 2s/epoch - 39ms/step
# Epoch 98/100
# 47/47 - 2s - loss: 8.3268 - val_loss: 8.2683 - 2s/epoch - 43ms/step
# Epoch 99/100
# 47/47 - 2s - loss: 8.2097 - val_loss: 8.1531 - 2s/epoch - 42ms/step
# Epoch 100/100
# 47/47 - 2s - loss: 8.0935 - val_loss: 8.0372 - 2s/epoch - 40ms/step
# 29/29 [==============================] - 1s 8ms/step
# MAE: 58.89827500977365
# MSE: 5317.230039338848
# R²: -9.684908621692623
# Average difference between actual and predicted values: 52.78%
# Epoch 1/100
# 47/47 - 2s - loss: 7.9783 - val_loss: 7.9229 - 2s/epoch - 42ms/step
# Epoch 2/100
# 47/47 - 2s - loss: 7.8640 - val_loss: 7.8079 - 2s/epoch - 40ms/step
# Epoch 3/100
# 47/47 - 2s - loss: 7.7506 - val_loss: 7.6954 - 2s/epoch - 40ms/step
# Epoch 4/100
# 47/47 - 2s - loss: 7.6383 - val_loss: 7.5827 - 2s/epoch - 40ms/step
# Epoch 5/100
# 47/47 - 2s - loss: 7.5268 - val_loss: 7.4723 - 2s/epoch - 39ms/step
# Epoch 6/100
# 47/47 - 2s - loss: 7.4164 - val_loss: 7.3618 - 2s/epoch - 42ms/step
# Epoch 7/100
# 47/47 - 2s - loss: 7.3068 - val_loss: 7.2536 - 2s/epoch - 41ms/step
# Epoch 8/100
# 47/47 - 2s - loss: 7.1982 - val_loss: 7.1453 - 2s/epoch - 43ms/step
# Epoch 9/100
# 47/47 - 2s - loss: 7.0906 - val_loss: 7.0394 - 2s/epoch - 43ms/step
# Epoch 10/100
# 47/47 - 2s - loss: 6.9839 - val_loss: 6.9318 - 2s/epoch - 43ms/step
# Epoch 11/100
# 47/47 - 2s - loss: 6.8781 - val_loss: 6.8258 - 2s/epoch - 46ms/step
# Epoch 12/100
# 47/47 - 2s - loss: 6.7732 - val_loss: 6.7229 - 2s/epoch - 46ms/step
# Epoch 13/100
# 47/47 - 2s - loss: 6.6693 - val_loss: 6.6181 - 2s/epoch - 44ms/step
# Epoch 14/100
# 47/47 - 2s - loss: 6.5663 - val_loss: 6.5163 - 2s/epoch - 46ms/step
# Epoch 15/100
# 47/47 - 2s - loss: 6.4643 - val_loss: 6.4137 - 2s/epoch - 45ms/step
# Epoch 16/100
# 47/47 - 2s - loss: 6.3631 - val_loss: 6.3139 - 2s/epoch - 46ms/step
# Epoch 17/100
# 47/47 - 2s - loss: 6.2629 - val_loss: 6.2144 - 2s/epoch - 44ms/step
# Epoch 18/100
# 47/47 - 2s - loss: 6.1636 - val_loss: 6.1154 - 2s/epoch - 46ms/step
# Epoch 19/100
# 47/47 - 2s - loss: 6.0653 - val_loss: 6.0169 - 2s/epoch - 45ms/step
# Epoch 20/100
# 47/47 - 2s - loss: 5.9678 - val_loss: 5.9204 - 2s/epoch - 43ms/step
# Epoch 21/100
# 47/47 - 2s - loss: 5.8712 - val_loss: 5.8254 - 2s/epoch - 43ms/step
# Epoch 22/100
# 47/47 - 2s - loss: 5.7756 - val_loss: 5.7291 - 2s/epoch - 45ms/step
# Epoch 23/100
# 47/47 - 2s - loss: 5.6809 - val_loss: 5.6351 - 2s/epoch - 44ms/step
# Epoch 24/100
# 47/47 - 2s - loss: 5.5871 - val_loss: 5.5427 - 2s/epoch - 47ms/step
# Epoch 25/100
# 47/47 - 2s - loss: 5.4942 - val_loss: 5.4506 - 2s/epoch - 43ms/step
# Epoch 26/100
# 47/47 - 2s - loss: 5.4022 - val_loss: 5.3578 - 2s/epoch - 40ms/step
# Epoch 27/100
# 47/47 - 2s - loss: 5.3111 - val_loss: 5.2672 - 2s/epoch - 40ms/step
# Epoch 28/100
# 47/47 - 2s - loss: 5.2209 - val_loss: 5.1780 - 2s/epoch - 39ms/step
# Epoch 29/100
# 47/47 - 2s - loss: 5.1316 - val_loss: 5.0880 - 2s/epoch - 37ms/step
# Epoch 30/100
# 47/47 - 2s - loss: 5.0432 - val_loss: 5.0006 - 2s/epoch - 41ms/step
# Epoch 31/100
# 47/47 - 2s - loss: 4.9557 - val_loss: 4.9129 - 2s/epoch - 38ms/step
# Epoch 32/100
# 47/47 - 2s - loss: 4.8691 - val_loss: 4.8271 - 2s/epoch - 37ms/step
# Epoch 33/100
# 47/47 - 2s - loss: 4.7834 - val_loss: 4.7433 - 2s/epoch - 37ms/step
# Epoch 34/100
# 47/47 - 2s - loss: 4.6986 - val_loss: 4.6581 - 2s/epoch - 38ms/step
# Epoch 35/100
# 47/47 - 2s - loss: 4.6146 - val_loss: 4.5754 - 2s/epoch - 37ms/step
# Epoch 36/100
# 47/47 - 2s - loss: 4.5315 - val_loss: 4.4919 - 2s/epoch - 37ms/step
# Epoch 37/100
# 47/47 - 2s - loss: 4.4494 - val_loss: 4.4097 - 2s/epoch - 37ms/step
# Epoch 38/100
# 47/47 - 2s - loss: 4.3681 - val_loss: 4.3296 - 2s/epoch - 38ms/step
# Epoch 39/100
# 47/47 - 2s - loss: 4.2876 - val_loss: 4.2496 - 2s/epoch - 37ms/step
# Epoch 40/100
# 47/47 - 2s - loss: 4.2081 - val_loss: 4.1715 - 2s/epoch - 39ms/step
# Epoch 41/100
# 47/47 - 2s - loss: 4.1294 - val_loss: 4.0913 - 2s/epoch - 37ms/step
# Epoch 42/100
# 47/47 - 2s - loss: 4.0516 - val_loss: 4.0143 - 2s/epoch - 37ms/step
# Epoch 43/100
# 47/47 - 2s - loss: 3.9747 - val_loss: 3.9386 - 2s/epoch - 37ms/step
# Epoch 44/100
# 47/47 - 2s - loss: 3.8986 - val_loss: 3.8615 - 2s/epoch - 37ms/step
# Epoch 45/100
# 47/47 - 2s - loss: 3.8234 - val_loss: 3.7877 - 2s/epoch - 37ms/step
# Epoch 46/100
# 47/47 - 2s - loss: 3.7490 - val_loss: 3.7138 - 2s/epoch - 37ms/step
# Epoch 47/100
# 47/47 - 2s - loss: 3.6755 - val_loss: 3.6416 - 2s/epoch - 37ms/step
# Epoch 48/100
# 47/47 - 2s - loss: 3.6029 - val_loss: 3.5684 - 2s/epoch - 37ms/step
# Epoch 49/100
# 47/47 - 2s - loss: 3.5311 - val_loss: 3.4972 - 2s/epoch - 37ms/step
# Epoch 50/100
# 47/47 - 2s - loss: 3.4602 - val_loss: 3.4270 - 2s/epoch - 44ms/step
# Epoch 51/100
# 47/47 - 2s - loss: 3.3902 - val_loss: 3.3572 - 2s/epoch - 41ms/step
# Epoch 52/100
# 47/47 - 2s - loss: 3.3209 - val_loss: 3.2885 - 2s/epoch - 39ms/step
# Epoch 53/100
# 47/47 - 2s - loss: 3.2526 - val_loss: 3.2195 - 2s/epoch - 39ms/step
# Epoch 54/100
# 47/47 - 2s - loss: 3.1851 - val_loss: 3.1527 - 2s/epoch - 40ms/step
# Epoch 55/100
# 47/47 - 2s - loss: 3.1183 - val_loss: 3.0867 - 2s/epoch - 39ms/step
# Epoch 56/100
# 47/47 - 2s - loss: 3.0525 - val_loss: 3.0232 - 2s/epoch - 39ms/step
# Epoch 57/100
# 47/47 - 2s - loss: 2.9875 - val_loss: 2.9571 - 2s/epoch - 38ms/step
# Epoch 58/100
# 47/47 - 2s - loss: 2.9233 - val_loss: 2.8949 - 2s/epoch - 38ms/step
# Epoch 59/100
# 47/47 - 2s - loss: 2.8599 - val_loss: 2.8303 - 2s/epoch - 38ms/step
# Epoch 60/100
# 47/47 - 2s - loss: 2.7974 - val_loss: 2.7689 - 2s/epoch - 39ms/step
# Epoch 61/100
# 47/47 - 2s - loss: 2.7357 - val_loss: 2.7071 - 2s/epoch - 38ms/step
# Epoch 62/100
# 47/47 - 2s - loss: 2.6748 - val_loss: 2.6473 - 2s/epoch - 39ms/step
# Epoch 63/100
# 47/47 - 2s - loss: 2.6147 - val_loss: 2.5881 - 2s/epoch - 43ms/step
# Epoch 64/100
# 47/47 - 2s - loss: 2.5555 - val_loss: 2.5284 - 2s/epoch - 41ms/step
# Epoch 65/100
# 47/47 - 2s - loss: 2.4971 - val_loss: 2.4718 - 2s/epoch - 39ms/step
# Epoch 66/100
# 47/47 - 2s - loss: 2.4394 - val_loss: 2.4128 - 2s/epoch - 37ms/step
# Epoch 67/100
# 47/47 - 2s - loss: 2.3826 - val_loss: 2.3570 - 2s/epoch - 38ms/step
# Epoch 68/100
# 47/47 - 2s - loss: 2.3266 - val_loss: 2.3014 - 2s/epoch - 37ms/step
# Epoch 69/100
# 47/47 - 2s - loss: 2.2714 - val_loss: 2.2468 - 2s/epoch - 41ms/step
# Epoch 70/100
# 47/47 - 2s - loss: 2.2170 - val_loss: 2.1914 - 2s/epoch - 48ms/step
# Epoch 71/100
# 47/47 - 2s - loss: 2.1634 - val_loss: 2.1400 - 2s/epoch - 39ms/step
# Epoch 72/100
# 47/47 - 2s - loss: 2.1106 - val_loss: 2.0873 - 2s/epoch - 38ms/step
# Epoch 73/100
# 47/47 - 2s - loss: 2.0586 - val_loss: 2.0345 - 2s/epoch - 39ms/step
# Epoch 74/100
# 47/47 - 2s - loss: 2.0073 - val_loss: 1.9847 - 2s/epoch - 38ms/step
# Epoch 75/100
# 47/47 - 2s - loss: 1.9569 - val_loss: 1.9351 - 2s/epoch - 38ms/step
# Epoch 76/100
# 47/47 - 2s - loss: 1.9072 - val_loss: 1.8852 - 2s/epoch - 39ms/step
# Epoch 77/100
# 47/47 - 2s - loss: 1.8583 - val_loss: 1.8365 - 2s/epoch - 43ms/step
# Epoch 78/100
# 47/47 - 2s - loss: 1.8102 - val_loss: 1.7881 - 2s/epoch - 44ms/step
# Epoch 79/100
# 47/47 - 2s - loss: 1.7629 - val_loss: 1.7412 - 2s/epoch - 43ms/step
# Epoch 80/100
# 47/47 - 2s - loss: 1.7163 - val_loss: 1.6952 - 2s/epoch - 40ms/step
# Epoch 81/100
# 47/47 - 2s - loss: 1.6705 - val_loss: 1.6507 - 2s/epoch - 43ms/step
# Epoch 82/100
# 47/47 - 2s - loss: 1.6254 - val_loss: 1.6053 - 2s/epoch - 43ms/step
# Epoch 83/100
# 47/47 - 2s - loss: 1.5811 - val_loss: 1.5622 - 2s/epoch - 40ms/step
# Epoch 84/100
# 47/47 - 2s - loss: 1.5376 - val_loss: 1.5193 - 2s/epoch - 38ms/step
# Epoch 85/100
# 47/47 - 2s - loss: 1.4948 - val_loss: 1.4758 - 2s/epoch - 37ms/step
# Epoch 86/100
# 47/47 - 2s - loss: 1.4527 - val_loss: 1.4347 - 2s/epoch - 37ms/step
# Epoch 87/100
# 47/47 - 2s - loss: 1.4114 - val_loss: 1.3932 - 2s/epoch - 37ms/step
# Epoch 88/100
# 47/47 - 2s - loss: 1.3709 - val_loss: 1.3537 - 2s/epoch - 39ms/step
# Epoch 89/100
# 47/47 - 2s - loss: 1.3310 - val_loss: 1.3151 - 2s/epoch - 41ms/step
# Epoch 90/100
# 47/47 - 2s - loss: 1.2919 - val_loss: 1.2745 - 2s/epoch - 38ms/step
# Epoch 91/100
# 47/47 - 2s - loss: 1.2536 - val_loss: 1.2371 - 2s/epoch - 39ms/step
# Epoch 92/100
# 47/47 - 2s - loss: 1.2159 - val_loss: 1.2006 - 2s/epoch - 38ms/step
# Epoch 93/100
# 47/47 - 2s - loss: 1.1790 - val_loss: 1.1628 - 2s/epoch - 38ms/step
# Epoch 94/100
# 47/47 - 2s - loss: 1.1427 - val_loss: 1.1269 - 2s/epoch - 38ms/step
# Epoch 95/100
# 47/47 - 2s - loss: 1.1072 - val_loss: 1.0921 - 2s/epoch - 38ms/step
# Epoch 96/100
# 47/47 - 2s - loss: 1.0724 - val_loss: 1.0584 - 2s/epoch - 39ms/step
# Epoch 97/100
# 47/47 - 2s - loss: 1.0383 - val_loss: 1.0235 - 2s/epoch - 41ms/step
# Epoch 98/100
# 47/47 - 2s - loss: 1.0049 - val_loss: 0.9909 - 2s/epoch - 38ms/step
# Epoch 99/100
# 47/47 - 2s - loss: 0.9721 - val_loss: 0.9580 - 2s/epoch - 39ms/step
# Epoch 100/100
# 47/47 - 2s - loss: 0.9401 - val_loss: 0.9266 - 2s/epoch - 39ms/step
# The model is not overfitting
