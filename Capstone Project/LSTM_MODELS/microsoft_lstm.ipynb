# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam
from keras.layers import Dropout
from keras import regularizers
import yfinance as yf
import pandas as pd
import numpy as np
import pandas_ta as ta 

# Load the data
data = yf.download('MSFT', start='1986-03-13', end='2024-01-01')

# Add new features
data['RSI'] = ta.rsi(data['Close'])
data['OBV'] = ta.obv(data['Close'], data['Volume'])
data['ATR'] = ta.atr(data['High'], data['Low'], data['Close'])
data['Yearly_MA'] = data['Close'].rolling(window=256).mean()
data['Garman Klass Vol'] = ((np.log(data['High']) - np.log(data['Low'])) ** 2) / 2 - (2 * np.log(2) - 1) * ((np.log(data['Adj Close']) - np.log(data['Open'])) ** 2)
data['Day'] = data.index.dayofweek
data['Month'] = data.index.month
data['Year'] = data.index.year

# Drop missing values
data = data.dropna()

# Keep only the 'Close' and the new features
data = data[['Close', 'RSI', 'OBV', 'ATR', 'Yearly_MA', 'Garman Klass Vol', 'Day', 'Month', 'Year']]

# Create a correlation matrix with the target 'Close'
correlation_matrix = data.corr()['Close'].sort_values(ascending=False)
print(correlation_matrix)

# Visualize correlation matrix, so we can read each feature clearly
plt.figure(figsize=(10, 7))
plt.bar(correlation_matrix.index, correlation_matrix.values)
plt.title('Correlation Matrix with Close', fontsize=16)
plt.xlabel('Features')
plt.ylabel('Correlation with Close')
plt.xticks(rotation=45)
plt.show()

# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = pd.DataFrame(scaler.fit_transform(data), columns=data.columns, index=data.index)

# Create a separate scaler for 'Close' prices
close_scaler = MinMaxScaler(feature_range=(0, 1))
close_scaler.fit(data[['Close']])

# Split into training and testing sets (80% training, 20% testing)
train_size = int(len(data_scaled) * 0.8)
train, test = data_scaled.iloc[0:train_size, :], data_scaled.iloc[train_size:len(data_scaled), :]

# Function to create a dataset for LSTM
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset.iloc[i:(i+look_back), 1:]  # Use only the features for input
        X.append(a.values)
        Y.append(dataset.iloc[i + look_back, 0])  # Use 'Close' for output
    return np.array(X), np.array(Y)

# Create datasets for training and testing
look_back = 10
X_train, Y_train = create_dataset(train, look_back)
X_test, Y_test = create_dataset(test, look_back)

# Reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# Adjust the learning rate
optimizer = Adam(learning_rate=0.0001)

model = Sequential()
model.add(LSTM(250, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2]), bias_regularizer=regularizers.l2(0.05)))
model.add(Dropout(0.2))
model.add(LSTM(250, bias_regularizer=regularizers.l2(0.05)))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer=optimizer)

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=5)

# Train the model
model.fit(X_train, Y_train, epochs=100, batch_size=64, verbose=2, validation_split=0.2, callbacks=[early_stopping])

# Predict the stock prices on the testing data
predictions = model.predict(X_test)
predictions = close_scaler.inverse_transform(predictions)  # Use the 'close_scaler' here

from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# Calculate the RMSE, MSE and R² for the test set
Y_test_transformed = close_scaler.inverse_transform(Y_test.reshape(-1, 1)).flatten()

# Calculate the RMSE, MSE, and R² for the test set
mae = mean_absolute_error(Y_test_transformed, predictions.flatten())
mse = mean_squared_error(Y_test_transformed, predictions.flatten())
r2 = r2_score(Y_test_transformed, predictions.flatten())

print('MAE:', mae)
print('MSE:', mse)
print('R²:', r2)

# Calculate the average difference between the actual and predicted values as a percentage
average_difference = np.mean(np.abs(predictions.flatten() - Y_test_transformed) / Y_test_transformed) * 100
print(f"Average difference between actual and predicted values: {average_difference:.2f}%")

# Compare the predicted prices with the actual values
Y_test = close_scaler.inverse_transform([Y_test])  # Use the 'close_scaler' here
plt.plot(Y_test[0])
plt.plot(predictions[:, 0])
plt.title('Microsoft Stock Price Prediction', fontsize=16)
plt.legend(['Actual', 'Predicted'])
plt.show()

# Plot train loss vs validation loss
history = model.fit(X_train, Y_train, epochs=100, batch_size=64, verbose=2, validation_split=0.2, callbacks=[early_stopping])
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Print overfitting or not
if history.history['val_loss'][-1] < history.history['loss'][-1]:
    print('The model is not overfitting')
else:
    print('The model is overfitting')

# Create a Niave forecast
data['Naive'] = data['Close'].shift(1)
data = data.dropna()

# Plot the naive forecast
plt.plot(data['Close'], label='Actual')
plt.plot(data['Naive'], label='Naive')
plt.legend()
plt.show()

# Compare Niave forecast with LSTM forecast
plt.plot(data['Close'][-100:], label='Actual')
plt.plot(data['Naive'][-100:], label='Naive')
plt.plot(data['Close'][-100:].index, predictions[-100:], label='LSTM')
plt.title('Microsoft Stock Price Prediction', fontsize=16)
plt.legend()
plt.show()
# Out:
# WARNING:tensorflow:From c:\Users\cjpai\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# c:\Users\cjpai\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# Close               1.000000
# Yearly_MA           0.987021
# ATR                 0.927352
# Year                0.722793
# Garman Klass Vol    0.629497
# OBV                 0.434842
# RSI                 0.063139
# Month               0.036098
# Day                 0.002995
# Name: Close, dtype: float64
# WARNING:tensorflow:From c:\Users\cjpai\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Epoch 1/100
# WARNING:tensorflow:From c:\Users\cjpai\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 93/93 - 8s - loss: 24.7727 - val_loss: 24.5395 - 8s/epoch - 85ms/step
# Epoch 2/100
# 93/93 - 4s - loss: 24.3133 - val_loss: 24.0828 - 4s/epoch - 39ms/step
# Epoch 3/100
# 93/93 - 4s - loss: 23.8605 - val_loss: 23.6335 - 4s/epoch - 38ms/step
# Epoch 4/100
# 93/93 - 4s - loss: 23.4139 - val_loss: 23.1898 - 4s/epoch - 38ms/step
# Epoch 5/100
# 93/93 - 4s - loss: 22.9735 - val_loss: 22.7527 - 4s/epoch - 38ms/step
# Epoch 6/100
# 93/93 - 4s - loss: 22.5391 - val_loss: 22.3215 - 4s/epoch - 39ms/step
# Epoch 7/100
# 93/93 - 4s - loss: 22.1106 - val_loss: 21.8956 - 4s/epoch - 38ms/step
# Epoch 8/100
# 93/93 - 4s - loss: 21.6879 - val_loss: 21.4757 - 4s/epoch - 39ms/step
# Epoch 9/100
# 93/93 - 4s - loss: 21.2708 - val_loss: 21.0621 - 4s/epoch - 39ms/step
# Epoch 10/100
# 93/93 - 4s - loss: 20.8595 - val_loss: 20.6529 - 4s/epoch - 38ms/step
# Epoch 11/100
# 93/93 - 4s - loss: 20.4536 - val_loss: 20.2500 - 4s/epoch - 38ms/step
# Epoch 12/100
# 93/93 - 4s - loss: 20.0532 - val_loss: 19.8524 - 4s/epoch - 38ms/step
# Epoch 13/100
# 93/93 - 4s - loss: 19.6581 - val_loss: 19.4602 - 4s/epoch - 38ms/step
# Epoch 14/100
# 93/93 - 4s - loss: 19.2683 - val_loss: 19.0730 - 4s/epoch - 38ms/step
# Epoch 15/100
# 93/93 - 4s - loss: 18.8837 - val_loss: 18.6909 - 4s/epoch - 38ms/step
# Epoch 16/100
# 93/93 - 4s - loss: 18.5043 - val_loss: 18.3140 - 4s/epoch - 39ms/step
# Epoch 17/100
# 93/93 - 4s - loss: 18.1299 - val_loss: 17.9423 - 4s/epoch - 40ms/step
# Epoch 18/100
# 93/93 - 4s - loss: 17.7605 - val_loss: 17.5754 - 4s/epoch - 39ms/step
# Epoch 19/100
# 93/93 - 4s - loss: 17.3960 - val_loss: 17.2137 - 4s/epoch - 39ms/step
# Epoch 20/100
# 93/93 - 4s - loss: 17.0363 - val_loss: 16.8562 - 4s/epoch - 39ms/step
# Epoch 21/100
# 93/93 - 4s - loss: 16.6814 - val_loss: 16.5036 - 4s/epoch - 38ms/step
# Epoch 22/100
# 93/93 - 4s - loss: 16.3313 - val_loss: 16.1560 - 4s/epoch - 38ms/step
# Epoch 23/100
# 93/93 - 4s - loss: 15.9859 - val_loss: 15.8129 - 4s/epoch - 38ms/step
# Epoch 24/100
# 93/93 - 4s - loss: 15.6451 - val_loss: 15.4745 - 4s/epoch - 38ms/step
# Epoch 25/100
# 93/93 - 4s - loss: 15.3088 - val_loss: 15.1404 - 4s/epoch - 38ms/step
# Epoch 26/100
# 93/93 - 4s - loss: 14.9771 - val_loss: 14.8111 - 4s/epoch - 38ms/step
# Epoch 27/100
# 93/93 - 4s - loss: 14.6499 - val_loss: 14.4861 - 4s/epoch - 38ms/step
# Epoch 28/100
# 93/93 - 4s - loss: 14.3271 - val_loss: 14.1657 - 4s/epoch - 38ms/step
# Epoch 29/100
# 93/93 - 4s - loss: 14.0086 - val_loss: 13.8493 - 4s/epoch - 38ms/step
# Epoch 30/100
# 93/93 - 4s - loss: 13.6945 - val_loss: 13.5374 - 4s/epoch - 38ms/step
# Epoch 31/100
# 93/93 - 4s - loss: 13.3848 - val_loss: 13.2297 - 4s/epoch - 38ms/step
# Epoch 32/100
# 93/93 - 4s - loss: 13.0792 - val_loss: 12.9265 - 4s/epoch - 39ms/step
# Epoch 33/100
# 93/93 - 4s - loss: 12.7779 - val_loss: 12.6273 - 4s/epoch - 38ms/step
# Epoch 34/100
# 93/93 - 4s - loss: 12.4809 - val_loss: 12.3322 - 4s/epoch - 39ms/step
# Epoch 35/100
# 93/93 - 4s - loss: 12.1879 - val_loss: 12.0417 - 4s/epoch - 38ms/step
# Epoch 36/100
# 93/93 - 4s - loss: 11.8991 - val_loss: 11.7550 - 4s/epoch - 38ms/step
# Epoch 37/100
# 93/93 - 4s - loss: 11.6144 - val_loss: 11.4720 - 4s/epoch - 38ms/step
# Epoch 38/100
# 93/93 - 4s - loss: 11.3338 - val_loss: 11.1936 - 4s/epoch - 38ms/step
# Epoch 39/100
# 93/93 - 4s - loss: 11.0571 - val_loss: 10.9190 - 4s/epoch - 38ms/step
# Epoch 40/100
# 93/93 - 4s - loss: 10.7845 - val_loss: 10.6485 - 4s/epoch - 38ms/step
# Epoch 41/100
# 93/93 - 4s - loss: 10.5159 - val_loss: 10.3819 - 4s/epoch - 38ms/step
# Epoch 42/100
# 93/93 - 4s - loss: 10.2513 - val_loss: 10.1190 - 4s/epoch - 38ms/step
# Epoch 43/100
# 93/93 - 4s - loss: 9.9906 - val_loss: 9.8605 - 4s/epoch - 38ms/step
# Epoch 44/100
# 93/93 - 4s - loss: 9.7337 - val_loss: 9.6058 - 4s/epoch - 38ms/step
# Epoch 45/100
# 93/93 - 4s - loss: 9.4808 - val_loss: 9.3549 - 4s/epoch - 38ms/step
# Epoch 46/100
# 93/93 - 4s - loss: 9.2318 - val_loss: 9.1074 - 4s/epoch - 38ms/step
# Epoch 47/100
# 93/93 - 4s - loss: 8.9866 - val_loss: 8.8643 - 4s/epoch - 38ms/step
# Epoch 48/100
# 93/93 - 4s - loss: 8.7452 - val_loss: 8.6249 - 4s/epoch - 39ms/step
# Epoch 49/100
# 93/93 - 4s - loss: 8.5076 - val_loss: 8.3891 - 4s/epoch - 38ms/step
# Epoch 50/100
# 93/93 - 4s - loss: 8.2738 - val_loss: 8.1574 - 4s/epoch - 38ms/step
# Epoch 51/100
# 93/93 - 4s - loss: 8.0438 - val_loss: 7.9291 - 4s/epoch - 39ms/step
# Epoch 52/100
# 93/93 - 4s - loss: 7.8175 - val_loss: 7.7047 - 4s/epoch - 41ms/step
# Epoch 53/100
# 93/93 - 4s - loss: 7.5949 - val_loss: 7.4842 - 4s/epoch - 39ms/step
# Epoch 54/100
# 93/93 - 4s - loss: 7.3761 - val_loss: 7.2671 - 4s/epoch - 38ms/step
# Epoch 55/100
# 93/93 - 4s - loss: 7.1609 - val_loss: 7.0538 - 4s/epoch - 38ms/step
# Epoch 56/100
# 93/93 - 4s - loss: 6.9495 - val_loss: 6.8442 - 4s/epoch - 38ms/step
# Epoch 57/100
# 93/93 - 4s - loss: 6.7417 - val_loss: 6.6383 - 4s/epoch - 38ms/step
# Epoch 58/100
# 93/93 - 4s - loss: 6.5375 - val_loss: 6.4360 - 4s/epoch - 38ms/step
# Epoch 59/100
# 93/93 - 4s - loss: 6.3370 - val_loss: 6.2371 - 4s/epoch - 38ms/step
# Epoch 60/100
# 93/93 - 4s - loss: 6.1400 - val_loss: 6.0419 - 4s/epoch - 38ms/step
# Epoch 61/100
# 93/93 - 4s - loss: 5.9467 - val_loss: 5.8506 - 4s/epoch - 38ms/step
# Epoch 62/100
# 93/93 - 5s - loss: 5.7570 - val_loss: 5.6628 - 5s/epoch - 49ms/step
# Epoch 63/100
# 93/93 - 6s - loss: 5.5708 - val_loss: 5.4784 - 6s/epoch - 63ms/step
# Epoch 64/100
# 93/93 - 5s - loss: 5.3881 - val_loss: 5.2974 - 5s/epoch - 55ms/step
# Epoch 65/100
# 93/93 - 4s - loss: 5.2090 - val_loss: 5.1201 - 4s/epoch - 47ms/step
# Epoch 66/100
# 93/93 - 4s - loss: 5.0334 - val_loss: 4.9463 - 4s/epoch - 43ms/step
# Epoch 67/100
# 93/93 - 4s - loss: 4.8614 - val_loss: 4.7761 - 4s/epoch - 39ms/step
# Epoch 68/100
# 93/93 - 4s - loss: 4.6928 - val_loss: 4.6090 - 4s/epoch - 38ms/step
# Epoch 69/100
# 93/93 - 4s - loss: 4.5276 - val_loss: 4.4456 - 4s/epoch - 39ms/step
# Epoch 70/100
# 93/93 - 4s - loss: 4.3659 - val_loss: 4.2858 - 4s/epoch - 39ms/step
# Epoch 71/100
# 93/93 - 4s - loss: 4.2077 - val_loss: 4.1293 - 4s/epoch - 38ms/step
# Epoch 72/100
# 93/93 - 4s - loss: 4.0529 - val_loss: 3.9762 - 4s/epoch - 39ms/step
# Epoch 73/100
# 93/93 - 4s - loss: 3.9014 - val_loss: 3.8264 - 4s/epoch - 38ms/step
# Epoch 74/100
# 93/93 - 4s - loss: 3.7534 - val_loss: 3.6800 - 4s/epoch - 38ms/step
# Epoch 75/100
# 93/93 - 4s - loss: 3.6087 - val_loss: 3.5371 - 4s/epoch - 38ms/step
# Epoch 76/100
# 93/93 - 4s - loss: 3.4674 - val_loss: 3.3974 - 4s/epoch - 38ms/step
# Epoch 77/100
# 93/93 - 4s - loss: 3.3294 - val_loss: 3.2614 - 4s/epoch - 38ms/step
# Epoch 78/100
# 93/93 - 4s - loss: 3.1947 - val_loss: 3.1283 - 4s/epoch - 39ms/step
# Epoch 79/100
# 93/93 - 4s - loss: 3.0633 - val_loss: 2.9985 - 4s/epoch - 39ms/step
# Epoch 80/100
# 93/93 - 4s - loss: 2.9352 - val_loss: 2.8720 - 4s/epoch - 38ms/step
# Epoch 81/100
# 93/93 - 4s - loss: 2.8103 - val_loss: 2.7489 - 4s/epoch - 39ms/step
# Epoch 82/100
# 93/93 - 4s - loss: 2.6887 - val_loss: 2.6288 - 4s/epoch - 41ms/step
# Epoch 83/100
# 93/93 - 4s - loss: 2.5702 - val_loss: 2.5119 - 4s/epoch - 40ms/step
# Epoch 84/100
# 93/93 - 4s - loss: 2.4550 - val_loss: 2.3982 - 4s/epoch - 40ms/step
# Epoch 85/100
# 93/93 - 4s - loss: 2.3429 - val_loss: 2.2879 - 4s/epoch - 41ms/step
# Epoch 86/100
# 93/93 - 4s - loss: 2.2340 - val_loss: 2.1805 - 4s/epoch - 40ms/step
# Epoch 87/100
# 93/93 - 4s - loss: 2.1282 - val_loss: 2.0762 - 4s/epoch - 40ms/step
# Epoch 88/100
# 93/93 - 4s - loss: 2.0255 - val_loss: 1.9751 - 4s/epoch - 40ms/step
# Epoch 89/100
# 93/93 - 4s - loss: 1.9259 - val_loss: 1.8771 - 4s/epoch - 39ms/step
# Epoch 90/100
# 93/93 - 4s - loss: 1.8293 - val_loss: 1.7821 - 4s/epoch - 39ms/step
# Epoch 91/100
# 93/93 - 4s - loss: 1.7358 - val_loss: 1.6901 - 4s/epoch - 39ms/step
# Epoch 92/100
# 93/93 - 4s - loss: 1.6452 - val_loss: 1.6010 - 4s/epoch - 39ms/step
# Epoch 93/100
# 93/93 - 4s - loss: 1.5577 - val_loss: 1.5149 - 4s/epoch - 39ms/step
# Epoch 94/100
# 93/93 - 4s - loss: 1.4730 - val_loss: 1.4319 - 4s/epoch - 38ms/step
# Epoch 95/100
# 93/93 - 4s - loss: 1.3913 - val_loss: 1.3515 - 4s/epoch - 40ms/step
# Epoch 96/100
# 93/93 - 4s - loss: 1.3125 - val_loss: 1.2740 - 4s/epoch - 39ms/step
# Epoch 97/100
# 93/93 - 4s - loss: 1.2365 - val_loss: 1.1996 - 4s/epoch - 39ms/step
# Epoch 98/100
# 93/93 - 4s - loss: 1.1633 - val_loss: 1.1279 - 4s/epoch - 39ms/step
# Epoch 99/100
# 93/93 - 4s - loss: 1.0929 - val_loss: 1.0589 - 4s/epoch - 39ms/step
# Epoch 100/100
# 93/93 - 4s - loss: 1.0252 - val_loss: 0.9926 - 4s/epoch - 39ms/step
# 58/58 [==============================] - 1s 8ms/step
# MAE: 135.20353242373517
# MSE: 25206.42973462778
# R²: -1.8707908177127455
# Average difference between actual and predicted values: 66.42%
# Epoch 1/100
# 93/93 - 4s - loss: 0.9603 - val_loss: 0.9290 - 4s/epoch - 41ms/step
# Epoch 2/100
# 93/93 - 4s - loss: 0.8981 - val_loss: 0.8683 - 4s/epoch - 41ms/step
# Epoch 3/100
# 93/93 - 4s - loss: 0.8384 - val_loss: 0.8099 - 4s/epoch - 44ms/step
# Epoch 4/100
# 93/93 - 4s - loss: 0.7814 - val_loss: 0.7541 - 4s/epoch - 43ms/step
# Epoch 5/100
# 93/93 - 4s - loss: 0.7270 - val_loss: 0.7011 - 4s/epoch - 45ms/step
# Epoch 6/100
# 93/93 - 4s - loss: 0.6750 - val_loss: 0.6504 - 4s/epoch - 47ms/step
# Epoch 7/100
# 93/93 - 4s - loss: 0.6256 - val_loss: 0.6020 - 4s/epoch - 46ms/step
# Epoch 8/100
# 93/93 - 4s - loss: 0.5785 - val_loss: 0.5563 - 4s/epoch - 44ms/step
# Epoch 9/100
# 93/93 - 5s - loss: 0.5339 - val_loss: 0.5129 - 5s/epoch - 49ms/step
# Epoch 10/100
# 93/93 - 4s - loss: 0.4916 - val_loss: 0.4717 - 4s/epoch - 48ms/step
# Epoch 11/100
# 93/93 - 4s - loss: 0.4515 - val_loss: 0.4326 - 4s/epoch - 48ms/step
# Epoch 12/100
# 93/93 - 4s - loss: 0.4137 - val_loss: 0.3962 - 4s/epoch - 46ms/step
# Epoch 13/100
# 93/93 - 4s - loss: 0.3781 - val_loss: 0.3618 - 4s/epoch - 47ms/step
# Epoch 14/100
# 93/93 - 5s - loss: 0.3446 - val_loss: 0.3293 - 5s/epoch - 49ms/step
# Epoch 15/100
# 93/93 - 5s - loss: 0.3132 - val_loss: 0.2988 - 5s/epoch - 58ms/step
# Epoch 16/100
# 93/93 - 4s - loss: 0.2838 - val_loss: 0.2704 - 4s/epoch - 48ms/step
# Epoch 17/100
# 93/93 - 4s - loss: 0.2563 - val_loss: 0.2440 - 4s/epoch - 46ms/step
# Epoch 18/100
# 93/93 - 4s - loss: 0.2308 - val_loss: 0.2192 - 4s/epoch - 46ms/step
# Epoch 19/100
# 93/93 - 4s - loss: 0.2070 - val_loss: 0.1964 - 4s/epoch - 45ms/step
# Epoch 20/100
# 93/93 - 4s - loss: 0.1850 - val_loss: 0.1751 - 4s/epoch - 45ms/step
# Epoch 21/100
# 93/93 - 4s - loss: 0.1648 - val_loss: 0.1559 - 4s/epoch - 45ms/step
# Epoch 22/100
# 93/93 - 4s - loss: 0.1461 - val_loss: 0.1381 - 4s/epoch - 45ms/step
# Epoch 23/100
# 93/93 - 4s - loss: 0.1290 - val_loss: 0.1217 - 4s/epoch - 45ms/step
# Epoch 24/100
# 93/93 - 4s - loss: 0.1134 - val_loss: 0.1068 - 4s/epoch - 45ms/step
# Epoch 25/100
# 93/93 - 4s - loss: 0.0992 - val_loss: 0.0933 - 4s/epoch - 45ms/step
# Epoch 26/100
# 93/93 - 4s - loss: 0.0863 - val_loss: 0.0813 - 4s/epoch - 45ms/step
# Epoch 27/100
# 93/93 - 4s - loss: 0.0747 - val_loss: 0.0703 - 4s/epoch - 45ms/step
# Epoch 28/100
# 93/93 - 4s - loss: 0.0643 - val_loss: 0.0605 - 4s/epoch - 47ms/step
# Epoch 29/100
# 93/93 - 4s - loss: 0.0551 - val_loss: 0.0515 - 4s/epoch - 45ms/step
# Epoch 30/100
# 93/93 - 4s - loss: 0.0468 - val_loss: 0.0440 - 4s/epoch - 45ms/step
# Epoch 31/100
# 93/93 - 4s - loss: 0.0396 - val_loss: 0.0371 - 4s/epoch - 45ms/step
# Epoch 32/100
# 93/93 - 4s - loss: 0.0332 - val_loss: 0.0312 - 4s/epoch - 45ms/step
# Epoch 33/100
# 93/93 - 4s - loss: 0.0277 - val_loss: 0.0261 - 4s/epoch - 45ms/step
# Epoch 34/100
# 93/93 - 4s - loss: 0.0229 - val_loss: 0.0215 - 4s/epoch - 45ms/step
# Epoch 35/100
# 93/93 - 4s - loss: 0.0187 - val_loss: 0.0179 - 4s/epoch - 45ms/step
# Epoch 36/100
# 93/93 - 4s - loss: 0.0152 - val_loss: 0.0145 - 4s/epoch - 45ms/step
# Epoch 37/100
# 93/93 - 4s - loss: 0.0123 - val_loss: 0.0119 - 4s/epoch - 44ms/step
# Epoch 38/100
# 93/93 - 4s - loss: 0.0098 - val_loss: 0.0096 - 4s/epoch - 43ms/step
# Epoch 39/100
# 93/93 - 4s - loss: 0.0077 - val_loss: 0.0077 - 4s/epoch - 45ms/step
# Epoch 40/100
# 93/93 - 4s - loss: 0.0060 - val_loss: 0.0063 - 4s/epoch - 48ms/step
# Epoch 41/100
# 93/93 - 4s - loss: 0.0047 - val_loss: 0.0050 - 4s/epoch - 46ms/step
# Epoch 42/100
# 93/93 - 4s - loss: 0.0036 - val_loss: 0.0043 - 4s/epoch - 46ms/step
# Epoch 43/100
# 93/93 - 4s - loss: 0.0027 - val_loss: 0.0032 - 4s/epoch - 46ms/step
# Epoch 44/100
# 93/93 - 4s - loss: 0.0020 - val_loss: 0.0027 - 4s/epoch - 46ms/step
# Epoch 45/100
# 93/93 - 4s - loss: 0.0015 - val_loss: 0.0024 - 4s/epoch - 45ms/step
# Epoch 46/100
# 93/93 - 4s - loss: 0.0011 - val_loss: 0.0019 - 4s/epoch - 46ms/step
# Epoch 47/100
# 93/93 - 4s - loss: 7.6912e-04 - val_loss: 0.0016 - 4s/epoch - 45ms/step
# Epoch 48/100
# 93/93 - 4s - loss: 5.4823e-04 - val_loss: 0.0014 - 4s/epoch - 46ms/step
# Epoch 49/100
# 93/93 - 4s - loss: 3.8575e-04 - val_loss: 0.0012 - 4s/epoch - 45ms/step
# Epoch 50/100
# 93/93 - 4s - loss: 2.6701e-04 - val_loss: 0.0014 - 4s/epoch - 45ms/step
# Epoch 51/100
# 93/93 - 4s - loss: 1.8649e-04 - val_loss: 0.0011 - 4s/epoch - 45ms/step
# Epoch 52/100
# 93/93 - 4s - loss: 1.3247e-04 - val_loss: 0.0012 - 4s/epoch - 45ms/step
# Epoch 53/100
# 93/93 - 4s - loss: 9.5389e-05 - val_loss: 0.0011 - 4s/epoch - 45ms/step
# Epoch 54/100
# 93/93 - 4s - loss: 6.8061e-05 - val_loss: 0.0012 - 4s/epoch - 45ms/step
# Epoch 55/100
# 93/93 - 4s - loss: 5.0854e-05 - val_loss: 0.0011 - 4s/epoch - 46ms/step
# Epoch 56/100
# 93/93 - 4s - loss: 4.1125e-05 - val_loss: 0.0013 - 4s/epoch - 45ms/step
# Epoch 57/100
# 93/93 - 4s - loss: 3.4444e-05 - val_loss: 0.0011 - 4s/epoch - 45ms/step
# Epoch 58/100
# 93/93 - 4s - loss: 3.1331e-05 - val_loss: 9.7289e-04 - 4s/epoch - 45ms/step
# Epoch 59/100
# 93/93 - 4s - loss: 2.9516e-05 - val_loss: 9.8039e-04 - 4s/epoch - 45ms/step
# Epoch 60/100
# 93/93 - 4s - loss: 2.9409e-05 - val_loss: 0.0012 - 4s/epoch - 44ms/step
# Epoch 61/100
# 93/93 - 4s - loss: 2.6941e-05 - val_loss: 0.0011 - 4s/epoch - 44ms/step
# Epoch 62/100
# 93/93 - 4s - loss: 2.6725e-05 - val_loss: 0.0012 - 4s/epoch - 44ms/step
# Epoch 63/100
# 93/93 - 4s - loss: 2.8211e-05 - val_loss: 0.0011 - 4s/epoch - 46ms/step
# The model is overfitting
