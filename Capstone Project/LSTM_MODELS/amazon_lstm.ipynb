# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam
from keras.layers import Dropout
from keras import regularizers
import yfinance as yf
import pandas as pd
import numpy as np
import pandas_ta as ta 

# Download Amazon's stock data from its IPO date till now
data = yf.download('AMZN', start='1997-05-15', end='2024-01-01')

# Add new features
data['RSI'] = ta.rsi(data['Close'])
data['OBV'] = ta.obv(data['Close'], data['Volume'])
data['ATR'] = ta.atr(data['High'], data['Low'], data['Close'])
data['Yearly_MA'] = data['Close'].rolling(window=256).mean()
data['Garman Klass Vol'] = ((np.log(data['High']) - np.log(data['Low'])) ** 2) / 2 - (2 * np.log(2) - 1) * ((np.log(data['Adj Close']) - np.log(data['Open'])) ** 2)
data['Day'] = data.index.dayofweek
data['Month'] = data.index.month
data['Year'] = data.index.year

# Drop missing values
data = data.dropna()

# Keep only the 'Close' and the new features
data = data[['Close', 'RSI', 'OBV', 'ATR', 'Yearly_MA', 'Garman Klass Vol', 'Day', 'Month', 'Year']]

# Create a correlation matrix with the target 'Close'
correlation_matrix = data.corr()['Close'].sort_values(ascending=False)
print(correlation_matrix)

# Visualize correlation matrix, so we can read each feature clearly
plt.figure(figsize=(10, 7))
plt.bar(correlation_matrix.index, correlation_matrix.values)
plt.title('Correlation Matrix with Close', fontsize=16)
plt.xlabel('Features')
plt.ylabel('Correlation with Close')
plt.xticks(rotation=45)
plt.show()

# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = pd.DataFrame(scaler.fit_transform(data), columns=data.columns, index=data.index)

# Create a separate scaler for 'Close' prices
close_scaler = MinMaxScaler(feature_range=(0, 1))
close_scaler.fit(data[['Close']])

# Split into training and testing sets (80% training, 20% testing)
train_size = int(len(data_scaled) * 0.8)
train, test = data_scaled.iloc[0:train_size, :], data_scaled.iloc[train_size:len(data_scaled), :]

# Function to create a dataset for LSTM
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset.iloc[i:(i+look_back), 1:]  # Use only the features for input
        X.append(a.values)
        Y.append(dataset.iloc[i + look_back, 0])  # Use 'Close' for output
    return np.array(X), np.array(Y)

# Create datasets for training and testing
look_back = 10
X_train, Y_train = create_dataset(train, look_back)
X_test, Y_test = create_dataset(test, look_back)

# Reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# Adjust the learning rate
optimizer = Adam(learning_rate=0.0001)

model = Sequential()
model.add(LSTM(250, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2]), bias_regularizer=regularizers.l2(0.05)))
model.add(Dropout(0.2))
model.add(LSTM(250, bias_regularizer=regularizers.l2(0.05)))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer=optimizer)

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=5)

# Train the model
model.fit(X_train, Y_train, epochs=100, batch_size=64, verbose=2, validation_split=0.2, callbacks=[early_stopping])

# Predict the stock prices on the testing data
predictions = model.predict(X_test)
predictions = close_scaler.inverse_transform(predictions)  # Use the 'close_scaler' here

from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# Calculate the RMSE, MSE and R² for the test set
Y_test_transformed = close_scaler.inverse_transform(Y_test.reshape(-1, 1)).flatten()

# Calculate the RMSE, MSE, and R² for the test set
mae = mean_absolute_error(Y_test_transformed, predictions.flatten())
mse = mean_squared_error(Y_test_transformed, predictions.flatten())
r2 = r2_score(Y_test_transformed, predictions.flatten())

print('MAE:', mae)
print('MSE:', mse)
print('R²:', r2)

# Calculate the average difference between the actual and predicted values as a percentage
average_difference = np.mean(np.abs(predictions.flatten() - Y_test_transformed) / Y_test_transformed) * 100
print(f"Average difference between actual and predicted values: {average_difference:.2f}%")

# Compare the predicted prices with the actual values
Y_test = close_scaler.inverse_transform([Y_test])  # Use the 'close_scaler' here
plt.plot(Y_test[0])
plt.plot(predictions[:, 0])
plt.title('Amazon Stock Price Prediction', fontsize=16)
plt.legend(['Actual', 'Predicted'])
plt.show()

# Plot train loss vs validation loss
history = model.fit(X_train, Y_train, epochs=100, batch_size=64, verbose=2, validation_split=0.2, callbacks=[early_stopping])
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Print overfitting or not
if history.history['val_loss'][-1] < history.history['loss'][-1]:
    print('The model is not overfitting')
else:
    print('The model is overfitting')

# Create a Niave forecast
data['Naive'] = data['Close'].shift(1)
data = data.dropna()

# Plot the naive forecast
plt.plot(data['Close'], label='Actual')
plt.plot(data['Naive'], label='Naive')
plt.legend()
plt.show()

# Compare Niave forecast with LSTM forecast
plt.plot(data['Close'][-100:], label='Actual')
plt.plot(data['Naive'][-100:], label='Naive')
plt.plot(data['Close'][-100:].index, predictions[-100:], label='LSTM')
plt.title('Amazon Stock Price Prediction', fontsize=16)
plt.legend()
plt.show()
# Out:
# WARNING:tensorflow:From c:\Users\cjpai\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# c:\Users\cjpai\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# Close               1.000000
# Yearly_MA           0.974962
# ATR                 0.919449
# Year                0.809910
# OBV                 0.776471
# RSI                 0.037238
# Month               0.031554
# Day                 0.000837
# Garman Klass Vol   -0.199496
# Name: Close, dtype: float64
# WARNING:tensorflow:From c:\Users\cjpai\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Epoch 1/100
# WARNING:tensorflow:From c:\Users\cjpai\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 65/65 - 7s - loss: 24.8426 - val_loss: 24.7041 - 7s/epoch - 105ms/step
# Epoch 2/100
# 65/65 - 3s - loss: 24.5202 - val_loss: 24.3750 - 3s/epoch - 39ms/step
# Epoch 3/100
# 65/65 - 3s - loss: 24.2010 - val_loss: 24.0508 - 3s/epoch - 39ms/step
# Epoch 4/100
# 65/65 - 2s - loss: 23.8850 - val_loss: 23.7321 - 2s/epoch - 38ms/step
# Epoch 5/100
# 65/65 - 3s - loss: 23.5720 - val_loss: 23.4188 - 3s/epoch - 39ms/step
# Epoch 6/100
# 65/65 - 3s - loss: 23.2621 - val_loss: 23.1101 - 3s/epoch - 40ms/step
# Epoch 7/100
# 65/65 - 2s - loss: 22.9550 - val_loss: 22.8040 - 2s/epoch - 38ms/step
# Epoch 8/100
# 65/65 - 3s - loss: 22.6510 - val_loss: 22.5009 - 3s/epoch - 39ms/step
# Epoch 9/100
# 65/65 - 2s - loss: 22.3498 - val_loss: 22.2008 - 2s/epoch - 38ms/step
# Epoch 10/100
# 65/65 - 2s - loss: 22.0515 - val_loss: 21.9044 - 2s/epoch - 38ms/step
# Epoch 11/100
# 65/65 - 2s - loss: 21.7560 - val_loss: 21.6095 - 2s/epoch - 38ms/step
# Epoch 12/100
# 65/65 - 2s - loss: 21.4633 - val_loss: 21.3182 - 2s/epoch - 38ms/step
# Epoch 13/100
# 65/65 - 2s - loss: 21.1734 - val_loss: 21.0296 - 2s/epoch - 38ms/step
# Epoch 14/100
# 65/65 - 2s - loss: 20.8862 - val_loss: 20.7430 - 2s/epoch - 38ms/step
# Epoch 15/100
# 65/65 - 3s - loss: 20.6017 - val_loss: 20.4598 - 3s/epoch - 40ms/step
# Epoch 16/100
# 65/65 - 2s - loss: 20.3199 - val_loss: 20.1796 - 2s/epoch - 38ms/step
# Epoch 17/100
# 65/65 - 3s - loss: 20.0407 - val_loss: 19.9012 - 3s/epoch - 39ms/step
# Epoch 18/100
# 65/65 - 2s - loss: 19.7641 - val_loss: 19.6272 - 2s/epoch - 38ms/step
# Epoch 19/100
# 65/65 - 2s - loss: 19.4902 - val_loss: 19.3533 - 2s/epoch - 38ms/step
# Epoch 20/100
# 65/65 - 3s - loss: 19.2188 - val_loss: 19.0835 - 3s/epoch - 39ms/step
# Epoch 21/100
# 65/65 - 2s - loss: 18.9499 - val_loss: 18.8163 - 2s/epoch - 38ms/step
# Epoch 22/100
# 65/65 - 2s - loss: 18.6835 - val_loss: 18.5511 - 2s/epoch - 38ms/step
# Epoch 23/100
# 65/65 - 3s - loss: 18.4196 - val_loss: 18.2880 - 3s/epoch - 38ms/step
# Epoch 24/100
# 65/65 - 2s - loss: 18.1582 - val_loss: 18.0279 - 2s/epoch - 38ms/step
# Epoch 25/100
# 65/65 - 3s - loss: 17.8992 - val_loss: 17.7701 - 3s/epoch - 39ms/step
# Epoch 26/100
# 65/65 - 3s - loss: 17.6427 - val_loss: 17.5143 - 3s/epoch - 39ms/step
# Epoch 27/100
# 65/65 - 2s - loss: 17.3885 - val_loss: 17.2615 - 2s/epoch - 38ms/step
# Epoch 28/100
# 65/65 - 2s - loss: 17.1367 - val_loss: 17.0110 - 2s/epoch - 38ms/step
# Epoch 29/100
# 65/65 - 2s - loss: 16.8872 - val_loss: 16.7624 - 2s/epoch - 38ms/step
# Epoch 30/100
# 65/65 - 2s - loss: 16.6401 - val_loss: 16.5170 - 2s/epoch - 38ms/step
# Epoch 31/100
# 65/65 - 2s - loss: 16.3953 - val_loss: 16.2728 - 2s/epoch - 38ms/step
# Epoch 32/100
# 65/65 - 2s - loss: 16.1528 - val_loss: 16.0320 - 2s/epoch - 38ms/step
# Epoch 33/100
# 65/65 - 2s - loss: 15.9125 - val_loss: 15.7927 - 2s/epoch - 38ms/step
# Epoch 34/100
# 65/65 - 2s - loss: 15.6745 - val_loss: 15.5554 - 2s/epoch - 38ms/step
# Epoch 35/100
# 65/65 - 3s - loss: 15.4388 - val_loss: 15.3211 - 3s/epoch - 39ms/step
# Epoch 36/100
# 65/65 - 3s - loss: 15.2052 - val_loss: 15.0885 - 3s/epoch - 39ms/step
# Epoch 37/100
# 65/65 - 3s - loss: 14.9739 - val_loss: 14.8581 - 3s/epoch - 39ms/step
# Epoch 38/100
# 65/65 - 2s - loss: 14.7447 - val_loss: 14.6308 - 2s/epoch - 38ms/step
# Epoch 39/100
# 65/65 - 3s - loss: 14.5177 - val_loss: 14.4041 - 3s/epoch - 39ms/step
# Epoch 40/100
# 65/65 - 3s - loss: 14.2929 - val_loss: 14.1807 - 3s/epoch - 40ms/step
# Epoch 41/100
# 65/65 - 3s - loss: 14.0702 - val_loss: 13.9591 - 3s/epoch - 39ms/step
# Epoch 42/100
# 65/65 - 3s - loss: 13.8496 - val_loss: 13.7393 - 3s/epoch - 39ms/step
# Epoch 43/100
# 65/65 - 3s - loss: 13.6312 - val_loss: 13.5220 - 3s/epoch - 39ms/step
# Epoch 44/100
# 65/65 - 3s - loss: 13.4148 - val_loss: 13.3068 - 3s/epoch - 40ms/step
# Epoch 45/100
# 65/65 - 3s - loss: 13.2006 - val_loss: 13.0936 - 3s/epoch - 40ms/step
# Epoch 46/100
# 65/65 - 3s - loss: 12.9884 - val_loss: 12.8821 - 3s/epoch - 41ms/step
# Epoch 47/100
# 65/65 - 3s - loss: 12.7782 - val_loss: 12.6732 - 3s/epoch - 39ms/step
# Epoch 48/100
# 65/65 - 3s - loss: 12.5701 - val_loss: 12.4663 - 3s/epoch - 39ms/step
# Epoch 49/100
# 65/65 - 3s - loss: 12.3641 - val_loss: 12.2612 - 3s/epoch - 40ms/step
# Epoch 50/100
# 65/65 - 3s - loss: 12.1601 - val_loss: 12.0585 - 3s/epoch - 39ms/step
# Epoch 51/100
# 65/65 - 3s - loss: 11.9580 - val_loss: 11.8571 - 3s/epoch - 39ms/step
# Epoch 52/100
# 65/65 - 3s - loss: 11.7580 - val_loss: 11.6580 - 3s/epoch - 38ms/step
# Epoch 53/100
# 65/65 - 3s - loss: 11.5600 - val_loss: 11.4610 - 3s/epoch - 39ms/step
# Epoch 54/100
# 65/65 - 3s - loss: 11.3640 - val_loss: 11.2663 - 3s/epoch - 40ms/step
# Epoch 55/100
# 65/65 - 3s - loss: 11.1699 - val_loss: 11.0730 - 3s/epoch - 40ms/step
# Epoch 56/100
# 65/65 - 3s - loss: 10.9778 - val_loss: 10.8815 - 3s/epoch - 39ms/step
# Epoch 57/100
# 65/65 - 3s - loss: 10.7877 - val_loss: 10.6927 - 3s/epoch - 39ms/step
# Epoch 58/100
# 65/65 - 3s - loss: 10.5995 - val_loss: 10.5056 - 3s/epoch - 39ms/step
# Epoch 59/100
# 65/65 - 2s - loss: 10.4132 - val_loss: 10.3202 - 2s/epoch - 38ms/step
# Epoch 60/100
# 65/65 - 2s - loss: 10.2289 - val_loss: 10.1370 - 2s/epoch - 38ms/step
# Epoch 61/100
# 65/65 - 3s - loss: 10.0465 - val_loss: 9.9552 - 3s/epoch - 41ms/step
# Epoch 62/100
# 65/65 - 3s - loss: 9.8660 - val_loss: 9.7764 - 3s/epoch - 52ms/step
# Epoch 63/100
# 65/65 - 3s - loss: 9.6874 - val_loss: 9.5982 - 3s/epoch - 51ms/step
# Epoch 64/100
# 65/65 - 3s - loss: 9.5108 - val_loss: 9.4227 - 3s/epoch - 45ms/step
# Epoch 65/100
# 65/65 - 3s - loss: 9.3360 - val_loss: 9.2485 - 3s/epoch - 46ms/step
# Epoch 66/100
# 65/65 - 3s - loss: 9.1630 - val_loss: 9.0768 - 3s/epoch - 53ms/step
# Epoch 67/100
# 65/65 - 4s - loss: 8.9920 - val_loss: 8.9068 - 4s/epoch - 62ms/step
# Epoch 68/100
# 65/65 - 4s - loss: 8.8228 - val_loss: 8.7383 - 4s/epoch - 54ms/step
# Epoch 69/100
# 65/65 - 4s - loss: 8.6555 - val_loss: 8.5719 - 4s/epoch - 56ms/step
# Epoch 70/100
# 65/65 - 3s - loss: 8.4901 - val_loss: 8.4077 - 3s/epoch - 47ms/step
# Epoch 71/100
# 65/65 - 3s - loss: 8.3264 - val_loss: 8.2451 - 3s/epoch - 47ms/step
# Epoch 72/100
# 65/65 - 3s - loss: 8.1647 - val_loss: 8.0839 - 3s/epoch - 48ms/step
# Epoch 73/100
# 65/65 - 3s - loss: 8.0048 - val_loss: 7.9249 - 3s/epoch - 51ms/step
# Epoch 74/100
# 65/65 - 3s - loss: 7.8467 - val_loss: 7.7678 - 3s/epoch - 50ms/step
# Epoch 75/100
# 65/65 - 3s - loss: 7.6904 - val_loss: 7.6124 - 3s/epoch - 51ms/step
# Epoch 76/100
# 65/65 - 3s - loss: 7.5359 - val_loss: 7.4587 - 3s/epoch - 48ms/step
# Epoch 77/100
# 65/65 - 4s - loss: 7.3833 - val_loss: 7.3073 - 4s/epoch - 58ms/step
# Epoch 78/100
# 65/65 - 3s - loss: 7.2324 - val_loss: 7.1570 - 3s/epoch - 45ms/step
# Epoch 79/100
# 65/65 - 3s - loss: 7.0834 - val_loss: 7.0093 - 3s/epoch - 44ms/step
# Epoch 80/100
# 65/65 - 3s - loss: 6.9361 - val_loss: 6.8629 - 3s/epoch - 51ms/step
# Epoch 81/100
# 65/65 - 3s - loss: 6.7906 - val_loss: 6.7181 - 3s/epoch - 51ms/step
# Epoch 82/100
# 65/65 - 3s - loss: 6.6470 - val_loss: 6.5753 - 3s/epoch - 46ms/step
# Epoch 83/100
# 65/65 - 3s - loss: 6.5051 - val_loss: 6.4341 - 3s/epoch - 46ms/step
# Epoch 84/100
# 65/65 - 3s - loss: 6.3649 - val_loss: 6.2953 - 3s/epoch - 46ms/step
# Epoch 85/100
# 65/65 - 3s - loss: 6.2266 - val_loss: 6.1576 - 3s/epoch - 44ms/step
# Epoch 86/100
# 65/65 - 3s - loss: 6.0899 - val_loss: 6.0220 - 3s/epoch - 49ms/step
# Epoch 87/100
# 65/65 - 3s - loss: 5.9551 - val_loss: 5.8881 - 3s/epoch - 50ms/step
# Epoch 88/100
# 65/65 - 3s - loss: 5.8220 - val_loss: 5.7558 - 3s/epoch - 51ms/step
# Epoch 89/100
# 65/65 - 3s - loss: 5.6906 - val_loss: 5.6254 - 3s/epoch - 47ms/step
# Epoch 90/100
# 65/65 - 3s - loss: 5.5610 - val_loss: 5.4968 - 3s/epoch - 48ms/step
# Epoch 91/100
# 65/65 - 3s - loss: 5.4331 - val_loss: 5.3695 - 3s/epoch - 45ms/step
# Epoch 92/100
# 65/65 - 3s - loss: 5.3069 - val_loss: 5.2440 - 3s/epoch - 48ms/step
# Epoch 93/100
# 65/65 - 4s - loss: 5.1825 - val_loss: 5.1202 - 4s/epoch - 57ms/step
# Epoch 94/100
# 65/65 - 4s - loss: 5.0598 - val_loss: 4.9987 - 4s/epoch - 67ms/step
# Epoch 95/100
# 65/65 - 3s - loss: 4.9388 - val_loss: 4.8787 - 3s/epoch - 48ms/step
# Epoch 96/100
# 65/65 - 3s - loss: 4.8195 - val_loss: 4.7602 - 3s/epoch - 49ms/step
# Epoch 97/100
# 65/65 - 3s - loss: 4.7018 - val_loss: 4.6433 - 3s/epoch - 51ms/step
# Epoch 98/100
# 65/65 - 3s - loss: 4.5859 - val_loss: 4.5285 - 3s/epoch - 50ms/step
# Epoch 99/100
# 65/65 - 3s - loss: 4.4717 - val_loss: 4.4148 - 3s/epoch - 50ms/step
# Epoch 100/100
# 65/65 - 3s - loss: 4.3592 - val_loss: 4.3035 - 3s/epoch - 45ms/step
# 40/40 [==============================] - 1s 10ms/step
# MAE: 16.234578488299956
# MSE: 570.7183280258721
# R²: 0.4279489081282033
# Average difference between actual and predicted values: 13.99%
# Epoch 1/100
# 65/65 - 3s - loss: 4.2483 - val_loss: 4.1932 - 3s/epoch - 48ms/step
# Epoch 2/100
# 65/65 - 3s - loss: 4.1391 - val_loss: 4.0853 - 3s/epoch - 50ms/step
# Epoch 3/100
# 65/65 - 3s - loss: 4.0316 - val_loss: 3.9785 - 3s/epoch - 46ms/step
# Epoch 4/100
# 65/65 - 3s - loss: 3.9257 - val_loss: 3.8736 - 3s/epoch - 47ms/step
# Epoch 5/100
# 65/65 - 4s - loss: 3.8215 - val_loss: 3.7700 - 4s/epoch - 56ms/step
# Epoch 6/100
# 65/65 - 4s - loss: 3.7190 - val_loss: 3.6683 - 4s/epoch - 67ms/step
# Epoch 7/100
# 65/65 - 3s - loss: 3.6180 - val_loss: 3.5679 - 3s/epoch - 46ms/step
# Epoch 8/100
# 65/65 - 3s - loss: 3.5187 - val_loss: 3.4694 - 3s/epoch - 46ms/step
# Epoch 9/100
# 65/65 - 3s - loss: 3.4211 - val_loss: 3.3728 - 3s/epoch - 45ms/step
# Epoch 10/100
# 65/65 - 3s - loss: 3.3251 - val_loss: 3.2773 - 3s/epoch - 51ms/step
# Epoch 11/100
# 65/65 - 3s - loss: 3.2307 - val_loss: 3.1844 - 3s/epoch - 50ms/step
# Epoch 12/100
# 65/65 - 3s - loss: 3.1379 - val_loss: 3.0920 - 3s/epoch - 45ms/step
# Epoch 13/100
# 65/65 - 3s - loss: 3.0467 - val_loss: 3.0016 - 3s/epoch - 43ms/step
# Epoch 14/100
# 65/65 - 3s - loss: 2.9571 - val_loss: 2.9131 - 3s/epoch - 40ms/step
# Epoch 15/100
# 65/65 - 3s - loss: 2.8690 - val_loss: 2.8257 - 3s/epoch - 42ms/step
# Epoch 16/100
# 65/65 - 3s - loss: 2.7826 - val_loss: 2.7401 - 3s/epoch - 42ms/step
# Epoch 17/100
# 65/65 - 3s - loss: 2.6978 - val_loss: 2.6557 - 3s/epoch - 41ms/step
# Epoch 18/100
# 65/65 - 3s - loss: 2.6145 - val_loss: 2.5734 - 3s/epoch - 43ms/step
# Epoch 19/100
# 65/65 - 3s - loss: 2.5328 - val_loss: 2.4925 - 3s/epoch - 39ms/step
# Epoch 20/100
# 65/65 - 3s - loss: 2.4526 - val_loss: 2.4134 - 3s/epoch - 40ms/step
# Epoch 21/100
# 65/65 - 3s - loss: 2.3740 - val_loss: 2.3352 - 3s/epoch - 40ms/step
# Epoch 22/100
# 65/65 - 3s - loss: 2.2969 - val_loss: 2.2591 - 3s/epoch - 40ms/step
# Epoch 23/100
# 65/65 - 3s - loss: 2.2214 - val_loss: 2.1844 - 3s/epoch - 40ms/step
# Epoch 24/100
# 65/65 - 3s - loss: 2.1474 - val_loss: 2.1113 - 3s/epoch - 40ms/step
# Epoch 25/100
# 65/65 - 3s - loss: 2.0749 - val_loss: 2.0396 - 3s/epoch - 40ms/step
# Epoch 26/100
# 65/65 - 3s - loss: 2.0039 - val_loss: 1.9696 - 3s/epoch - 41ms/step
# Epoch 27/100
# 65/65 - 3s - loss: 1.9344 - val_loss: 1.9004 - 3s/epoch - 41ms/step
# Epoch 28/100
# 65/65 - 3s - loss: 1.8664 - val_loss: 1.8330 - 3s/epoch - 42ms/step
# Epoch 29/100
# 65/65 - 3s - loss: 1.7999 - val_loss: 1.7672 - 3s/epoch - 41ms/step
# Epoch 30/100
# 65/65 - 3s - loss: 1.7348 - val_loss: 1.7029 - 3s/epoch - 41ms/step
# Epoch 31/100
# 65/65 - 3s - loss: 1.6713 - val_loss: 1.6403 - 3s/epoch - 43ms/step
# Epoch 32/100
# 65/65 - 3s - loss: 1.6091 - val_loss: 1.5788 - 3s/epoch - 40ms/step
# Epoch 33/100
# 65/65 - 3s - loss: 1.5485 - val_loss: 1.5187 - 3s/epoch - 39ms/step
# Epoch 34/100
# 65/65 - 2s - loss: 1.4892 - val_loss: 1.4604 - 2s/epoch - 38ms/step
# Epoch 35/100
# 65/65 - 3s - loss: 1.4314 - val_loss: 1.4031 - 3s/epoch - 39ms/step
# Epoch 36/100
# 65/65 - 3s - loss: 1.3750 - val_loss: 1.3479 - 3s/epoch - 40ms/step
# Epoch 37/100
# 65/65 - 3s - loss: 1.3200 - val_loss: 1.2933 - 3s/epoch - 39ms/step
# Epoch 38/100
# 65/65 - 2s - loss: 1.2664 - val_loss: 1.2405 - 2s/epoch - 38ms/step
# Epoch 39/100
# 65/65 - 2s - loss: 1.2142 - val_loss: 1.1886 - 2s/epoch - 38ms/step
# Epoch 40/100
# 65/65 - 2s - loss: 1.1633 - val_loss: 1.1385 - 2s/epoch - 38ms/step
# Epoch 41/100
# 65/65 - 2s - loss: 1.1138 - val_loss: 1.0902 - 2s/epoch - 38ms/step
# Epoch 42/100
# 65/65 - 2s - loss: 1.0657 - val_loss: 1.0424 - 2s/epoch - 38ms/step
# Epoch 43/100
# 65/65 - 2s - loss: 1.0189 - val_loss: 0.9962 - 2s/epoch - 38ms/step
# Epoch 44/100
# 65/65 - 2s - loss: 0.9734 - val_loss: 0.9518 - 2s/epoch - 38ms/step
# Epoch 45/100
# 65/65 - 2s - loss: 0.9292 - val_loss: 0.9077 - 2s/epoch - 38ms/step
# Epoch 46/100
# 65/65 - 2s - loss: 0.8863 - val_loss: 0.8655 - 2s/epoch - 38ms/step
# Epoch 47/100
# 65/65 - 2s - loss: 0.8447 - val_loss: 0.8246 - 2s/epoch - 38ms/step
# Epoch 48/100
# 65/65 - 2s - loss: 0.8044 - val_loss: 0.7849 - 2s/epoch - 38ms/step
# Epoch 49/100
# 65/65 - 2s - loss: 0.7654 - val_loss: 0.7468 - 2s/epoch - 38ms/step
# Epoch 50/100
# 65/65 - 3s - loss: 0.7275 - val_loss: 0.7095 - 3s/epoch - 39ms/step
# Epoch 51/100
# 65/65 - 2s - loss: 0.6910 - val_loss: 0.6735 - 2s/epoch - 38ms/step
# Epoch 52/100
# 65/65 - 3s - loss: 0.6556 - val_loss: 0.6390 - 3s/epoch - 39ms/step
# Epoch 53/100
# 65/65 - 3s - loss: 0.6214 - val_loss: 0.6051 - 3s/epoch - 39ms/step
# Epoch 54/100
# 65/65 - 2s - loss: 0.5885 - val_loss: 0.5727 - 2s/epoch - 38ms/step
# Epoch 55/100
# 65/65 - 2s - loss: 0.5566 - val_loss: 0.5418 - 2s/epoch - 38ms/step
# Epoch 56/100
# 65/65 - 2s - loss: 0.5260 - val_loss: 0.5116 - 2s/epoch - 38ms/step
# Epoch 57/100
# 65/65 - 2s - loss: 0.4964 - val_loss: 0.4827 - 2s/epoch - 38ms/step
# Epoch 58/100
# 65/65 - 2s - loss: 0.4680 - val_loss: 0.4550 - 2s/epoch - 38ms/step
# Epoch 59/100
# 65/65 - 3s - loss: 0.4407 - val_loss: 0.4285 - 3s/epoch - 39ms/step
# Epoch 60/100
# 65/65 - 2s - loss: 0.4145 - val_loss: 0.4026 - 2s/epoch - 38ms/step
# Epoch 61/100
# 65/65 - 2s - loss: 0.3894 - val_loss: 0.3777 - 2s/epoch - 38ms/step
# Epoch 62/100
# 65/65 - 2s - loss: 0.3653 - val_loss: 0.3544 - 2s/epoch - 38ms/step
# Epoch 63/100
# 65/65 - 2s - loss: 0.3422 - val_loss: 0.3321 - 2s/epoch - 38ms/step
# Epoch 64/100
# 65/65 - 2s - loss: 0.3201 - val_loss: 0.3103 - 2s/epoch - 38ms/step
# Epoch 65/100
# 65/65 - 2s - loss: 0.2990 - val_loss: 0.2896 - 2s/epoch - 38ms/step
# Epoch 66/100
# 65/65 - 2s - loss: 0.2789 - val_loss: 0.2697 - 2s/epoch - 38ms/step
# Epoch 67/100
# 65/65 - 2s - loss: 0.2597 - val_loss: 0.2515 - 2s/epoch - 38ms/step
# Epoch 68/100
# 65/65 - 2s - loss: 0.2415 - val_loss: 0.2332 - 2s/epoch - 38ms/step
# Epoch 69/100
# 65/65 - 2s - loss: 0.2242 - val_loss: 0.2165 - 2s/epoch - 38ms/step
# Epoch 70/100
# 65/65 - 2s - loss: 0.2077 - val_loss: 0.2005 - 2s/epoch - 38ms/step
# Epoch 71/100
# 65/65 - 2s - loss: 0.1921 - val_loss: 0.1850 - 2s/epoch - 38ms/step
# Epoch 72/100
# 65/65 - 2s - loss: 0.1774 - val_loss: 0.1709 - 2s/epoch - 38ms/step
# Epoch 73/100
# 65/65 - 2s - loss: 0.1635 - val_loss: 0.1577 - 2s/epoch - 38ms/step
# Epoch 74/100
# 65/65 - 3s - loss: 0.1503 - val_loss: 0.1446 - 3s/epoch - 39ms/step
# Epoch 75/100
# 65/65 - 3s - loss: 0.1380 - val_loss: 0.1326 - 3s/epoch - 40ms/step
# Epoch 76/100
# 65/65 - 2s - loss: 0.1264 - val_loss: 0.1218 - 2s/epoch - 38ms/step
# Epoch 77/100
# 65/65 - 2s - loss: 0.1155 - val_loss: 0.1107 - 2s/epoch - 38ms/step
# Epoch 78/100
# 65/65 - 3s - loss: 0.1052 - val_loss: 0.1009 - 3s/epoch - 40ms/step
# Epoch 79/100
# 65/65 - 3s - loss: 0.0957 - val_loss: 0.0920 - 3s/epoch - 40ms/step
# Epoch 80/100
# 65/65 - 3s - loss: 0.0868 - val_loss: 0.0836 - 3s/epoch - 41ms/step
# Epoch 81/100
# 65/65 - 3s - loss: 0.0786 - val_loss: 0.0755 - 3s/epoch - 46ms/step
# Epoch 82/100
# 65/65 - 3s - loss: 0.0709 - val_loss: 0.0680 - 3s/epoch - 40ms/step
# Epoch 83/100
# 65/65 - 2s - loss: 0.0638 - val_loss: 0.0612 - 2s/epoch - 38ms/step
# Epoch 84/100
# 65/65 - 2s - loss: 0.0572 - val_loss: 0.0549 - 2s/epoch - 38ms/step
# Epoch 85/100
# 65/65 - 3s - loss: 0.0512 - val_loss: 0.0490 - 3s/epoch - 39ms/step
# Epoch 86/100
# 65/65 - 3s - loss: 0.0457 - val_loss: 0.0435 - 3s/epoch - 39ms/step
# Epoch 87/100
# 65/65 - 3s - loss: 0.0406 - val_loss: 0.0389 - 3s/epoch - 39ms/step
# Epoch 88/100
# 65/65 - 3s - loss: 0.0360 - val_loss: 0.0345 - 3s/epoch - 40ms/step
# Epoch 89/100
# 65/65 - 3s - loss: 0.0317 - val_loss: 0.0306 - 3s/epoch - 41ms/step
# Epoch 90/100
# 65/65 - 3s - loss: 0.0279 - val_loss: 0.0267 - 3s/epoch - 42ms/step
# Epoch 91/100
# 65/65 - 3s - loss: 0.0245 - val_loss: 0.0239 - 3s/epoch - 47ms/step
# Epoch 92/100
# 65/65 - 3s - loss: 0.0213 - val_loss: 0.0204 - 3s/epoch - 44ms/step
# Epoch 93/100
# 65/65 - 3s - loss: 0.0186 - val_loss: 0.0179 - 3s/epoch - 42ms/step
# Epoch 94/100
# 65/65 - 3s - loss: 0.0161 - val_loss: 0.0155 - 3s/epoch - 39ms/step
# Epoch 95/100
# 65/65 - 2s - loss: 0.0138 - val_loss: 0.0135 - 2s/epoch - 38ms/step
# Epoch 96/100
# 65/65 - 3s - loss: 0.0119 - val_loss: 0.0119 - 3s/epoch - 39ms/step
# Epoch 97/100
# 65/65 - 2s - loss: 0.0101 - val_loss: 0.0101 - 2s/epoch - 38ms/step
# Epoch 98/100
# 65/65 - 2s - loss: 0.0086 - val_loss: 0.0085 - 2s/epoch - 38ms/step
# Epoch 99/100
# 65/65 - 3s - loss: 0.0073 - val_loss: 0.0073 - 3s/epoch - 39ms/step
# Epoch 100/100
# 65/65 - 3s - loss: 0.0061 - val_loss: 0.0062 - 3s/epoch - 38ms/step
# The model is overfitting
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 158
#     155 plt.show()
#     157 # Create a pandas Series for predictions with the date index from actual data
# --> 158 predictions_series = pd.Series(predictions.flatten(), index=data['Close'][-100:].index)
#     160 # Now you can easily compare the predictions with actual values by date
#     161 print(predictions_series.head())  # Check the first few predictions with dates
#
# File c:\Users\cjpai\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:574, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     572     index = default_index(len(data))
#     573 elif is_list_like(data):
# --> 574     com.require_length_match(data, index)
#     576 # create/copy the manager
#     577 if isinstance(data, (SingleBlockManager, SingleArrayManager)):
#
# File c:\Users\cjpai\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\common.py:571, in require_length_match(data, index)
#     567 """
#     568 Check the length of data matches the length of the index.
#     569 """
#     570 if len(data) != len(index):
# --> 571     raise ValueError(
#     572         "Length of values "
#     573         f"({len(data)}) "
#     574         "does not match length of index "
#     575         f"({len(index)})"
#     576     )
#
# ValueError: Length of values (1279) does not match length of index (100)
